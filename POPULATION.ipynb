# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mushe\\Downloads'

# %%
os.chdir('C:\\Users\\mushe\\Downloads')

# %%
df = pd.read_csv("world_population.csv")

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.tail()
# Out:
#      Rank CCA3  Country/Territory   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
for column in df.columns:
    print(f"{column} ---> {df[column].nunique()}")
# Out:
# Rank ---> 234
# CCA3 ---> 234
# Country/Territory ---> 234
# Capital ---> 234
# Continent ---> 6
# 2022 Population ---> 234
# 2020 Population ---> 234
# 2015 Population ---> 234
# 2010 Population ---> 234
# 2000 Population ---> 234
# 1990 Population ---> 234
# 1980 Population ---> 234
# 1970 Population ---> 234
# Area (km²) ---> 233
# Density (per km²) ---> 234
# Growth Rate ---> 180
# World Population Percentage ---> 70

# %%
df.describe().T.sort_values("50%", ascending = False).style.background_gradient(cmap = "RdPu")\
    .bar(subset = ["mean"], color = "red").bar(subset = ["max"], color = "green")
# Out:
# <style type="text/css">
# #T_4cfbf_row0_col0, #T_4cfbf_row1_col0, #T_4cfbf_row2_col0, #T_4cfbf_row3_col0, #T_4cfbf_row4_col0, #T_4cfbf_row5_col0, #T_4cfbf_row6_col0, #T_4cfbf_row7_col0, #T_4cfbf_row8_col0, #T_4cfbf_row8_col3, #T_4cfbf_row9_col0, #T_4cfbf_row9_col2, #T_4cfbf_row9_col3, #T_4cfbf_row9_col4, #T_4cfbf_row9_col5, #T_4cfbf_row9_col6, #T_4cfbf_row10_col0, #T_4cfbf_row10_col2, #T_4cfbf_row10_col3, #T_4cfbf_row10_col4, #T_4cfbf_row10_col5, #T_4cfbf_row10_col6, #T_4cfbf_row11_col0, #T_4cfbf_row11_col2, #T_4cfbf_row11_col3, #T_4cfbf_row11_col4, #T_4cfbf_row11_col5, #T_4cfbf_row11_col6, #T_4cfbf_row12_col0, #T_4cfbf_row12_col2, #T_4cfbf_row12_col3, #T_4cfbf_row12_col4, #T_4cfbf_row12_col5, #T_4cfbf_row12_col6 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_4cfbf_row0_col1 {
#   background-color: #49006a;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, red 100.0%, transparent 100.0%);
# }
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop("CCA3", axis = 1, inplace = True)
df.rename({"Country/Territory":"Country", 
          '2022 Population': 2022,
          '2020 Population': 2020,
          '2015 Population': 2015, 
          '2010 Population': 2010, 
          '2000 Population': 2000, 
          '1990 Population': 1990, 
          '1980 Population': 1980, 
          '1970 Population': 1970}, axis = 1, inplace = True)
df
# Out:
#      Rank            Country           Capital Continent      2022      2020  \
# 0      36        Afghanistan             Kabul      Asia  41128771  38972230
# 1     138            Albania            Tirana    Europe   2842321   2866849
# 2      34            Algeria           Algiers    Africa  44903225  43451666
# 3     213     American Samoa         Pago Pago   Oceania     44273     46189
# 4     203            Andorra  Andorra la Vella    Europe     79824     77700
# ..    ...                ...               ...       ...       ...       ...
# 229   226  Wallis and Futuna          Mata-Utu   Oceania     11572     11655
# 230   172     Western Sahara          El Aaiún    Africa    575986    556048
# 231    46              Yemen             Sanaa      Asia  33696614  32284046
# 232    63             Zambia            Lusaka    Africa  20017675  18927715
# 233    74           Zimbabwe            Harare    Africa  16320537  15669666
#
# ...

# %%
for column in df.columns[4:12]:
    df[column] = df[column].astype(int)

# %%
plt.figure(figsize=(10,8))
sns.histplot(df['World Population Percentage'].dropna(), bins=20, kde=True)
plt.title('World Population Percentage')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(df['Area (km²)'].dropna(), bins=20, kde=True)
plt.title('Population in 1970')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(df['Density (per km²)'].dropna(), bins=20, kde=True)
plt.title('Population in 1970')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(df['Growth Rate'].dropna(), bins=20, kde=True)
plt.title('Population in 1970')
plt.show()

# %%
# Set a new column is "Density" to use hue for pairplot
bins = np.linspace(min(df[2022]), max(df[2022]), 3)
df["Density"] = pd.cut(df[2022], bins, labels = ["Low", "High"])

sns.pairplot(data = df, hue = "Density")
plt.tight_layout
plt.show()
